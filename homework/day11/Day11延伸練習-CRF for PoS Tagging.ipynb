# %% [markdown]
# ## 查看已安裝的套件

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.11.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.12
# anaconda-project                   0.8.3
# aniso8601                          8.1.0
# argh                               0.26.2
# asn1crypto                         1.3.0
# astroid                            2.4.2
# astropy                            4.0.1.post1
# astunparse                         1.6.3
# atomicwrites                       1.4.0
# attrs                              19.3.0
# autopep8                           1.5.3
# Babel                              2.8.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# ...

# %% [markdown]
# ## 下載需要的套件

# %%
pip install nltk sklearn_crfsuite
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 載入需要的套件

# %%
##資料來源：https://medium.com/analytics-vidhya/pos-tagging-using-conditional-random-fields-92077e5eaa31

# tutorial: https://sklearn-crfsuite.readthedocs.io/en/latest/tutorial.html#tutorial
#pip install nltk

# nltk: aka natural language toolkit
import nltk

import re
#pip install sklearn_crfsuite
from sklearn_crfsuite import CRF
from sklearn_crfsuite import metrics
from sklearn_crfsuite import scorers
#pip install scikit-learn
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---

# %% [markdown]
# ## 下載語料庫(corpus/ corpora)的方式：
# 1. 在 command line , 進入 python IDE 模式, 執行 nltk.download() 指令, 查看要下載的 nltk 資料集
# 2. 在 jupyter notebook 直接下載: nltk.download("corpus 名稱")

# %% [markdown]
# #### 1. 在 command line , 進入 python IDE 模式, 執行 nltk.download() 指令, 查看要下載的 nltk 語料庫

# %%
# run in command line, then will open NLTK downloader  #
# python
# nltk.download()

# %% [markdown]
# #### 2. 在 jupyter notebook 直接下載: nltk.download("corpus 名稱")

# %%
nltk.download("treebank")
nltk.download("universal_tagset")
nltk.download("brown")
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\s1900\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\s1900\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\s1900\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %% [markdown]
# ## 載入 語料庫(corpus/corpora)

# %%
from nltk.corpus import treebank, brown, twitter_samples

# %% [markdown]
# ### 查看是否有成功載入資料集

# %%
# 測試 treebank
print('type(treebank):', type(treebank))
treebank.words()
# Out:
# type(treebank): <class 'nltk.corpus.reader.bracket_parse.BracketParseCorpusReader'>
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', ...]

# %%
# 測試 brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
twitter_samples.tokenized()
# Out:
# [['hopeless', 'for', 'tmr', ':('],
#  ['Everything',
#   'in',
#   'the',
#   'kids',
#   'section',
#   'of',
#   'IKEA',
#   'is',
#   'so',
#   'cute',
#   '.',
#   'Shame',
#   "I'm",
#   'nearly',
#   '19',
#   'in',
#   '2',
#   'months',
#   ':('],
#  ['@Hegelbon',
#   'That',
#   'heart',
#   'sliding',
#   'into',
#   'the',
#   'waste',
#   'basket',
#   '.',
#   ':('],
#  ['“',
#   '@ketchBurning',
#   ':',
#   'I',
#   'hate',
#   'Japanese',
#   'call',
#   'him',
#   '"',
#   'bani',
#   '"',
#   ':(',
#   ':(',
#   '”',
#   'Me',
#   'too'],
#  ['Dang', 'starting', 'next', 'week', 'I', 'have', '"', 'work', '"', ':('],
#  ['oh',
#   'god',
#   ',',
#   'my',
#   'babies',
#   "'",
#   'faces',
#   ':(',
#   'https://t.co/9fcwGvaki0'],
#  ['@RileyMcDonough', 'make', 'me', 'smile', ':(', '('],
#  ['@f0ggstar',
#   '@stuartthull',
#   'work',
#   'neighbour',
#   'on',
#   'motors',
#   '.',
#   'Asked',
#   'why',
#   'and',
#   'he',
#   'said',
#   'hates',
#   'the',
# ...

# %% [markdown]
# ## 語料庫的常用方法

# %%
# treebank.words()
# treebank.sents()
# treebank.

# %%
# 印出前面幾個字
treebank.words()
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', ...]

# %%
# 切割句子
treebank.sents()
# Out:
# [['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.'], ['Mr.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N.V.', ',', 'the', 'Dutch', 'publishing', 'group', '.'], ...]

# %%
# 針對 sentence 詞性標註
treebank.tagged_sents()
# Out:
# [[('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('will', 'MD'), ('join', 'VB'), ('the', 'DT'), ('board', 'NN'), ('as', 'IN'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')], [('Mr.', 'NNP'), ('Vinken', 'NNP'), ('is', 'VBZ'), ('chairman', 'NN'), ('of', 'IN'), ('Elsevier', 'NNP'), ('N.V.', 'NNP'), (',', ','), ('the', 'DT'), ('Dutch', 'NNP'), ('publishing', 'VBG'), ('group', 'NN'), ('.', '.')], ...]

# %%
# 針對 words 詞性標註
treebank.tagged_words()
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ...]

# %%
# 印出 pos 的樹狀圖
treebank.parsed_sents()
# Out:
# [Tree('S', [Tree('NP-SBJ', [Tree('NP', [Tree('NNP', ['Pierre']), Tree('NNP', ['Vinken'])]), Tree(',', [',']), Tree('ADJP', [Tree('NP', [Tree('CD', ['61']), Tree('NNS', ['years'])]), Tree('JJ', ['old'])]), Tree(',', [','])]), Tree('VP', [Tree('MD', ['will']), Tree('VP', [Tree('VB', ['join']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['board'])]), Tree('PP-CLR', [Tree('IN', ['as']), Tree('NP', [Tree('DT', ['a']), Tree('JJ', ['nonexecutive']), Tree('NN', ['director'])])]), Tree('NP-TMP', [Tree('NNP', ['Nov.']), Tree('CD', ['29'])])])]), Tree('.', ['.'])]), Tree('S', [Tree('NP-SBJ', [Tree('NNP', ['Mr.']), Tree('NNP', ['Vinken'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('NP-PRD', [Tree('NP', [Tree('NN', ['chairman'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP', [Tree('NNP', ['Elsevier']), Tree('NNP', ['N.V.'])]), Tree(',', [',']), Tree('NP', [Tree('DT', ['the']), Tree('NNP', ['Dutch']), Tree('VBG', ['publishing']), Tree('NN', ['group'])])])])])]), Tree('.', ['.'])]), ...]

# %%
# 將 pos 印成 raw 格式
treebank.raw().split('\n')
# Out:
# ['',
#  '( (S ',
#  '    (NP-SBJ ',
#  '      (NP (NNP Pierre) (NNP Vinken) )',
#  '      (, ,) ',
#  '      (ADJP ',
#  '        (NP (CD 61) (NNS years) )',
#  '        (JJ old) )',
#  '      (, ,) )',
#  '    (VP (MD will) ',
#  '      (VP (VB join) ',
#  '        (NP (DT the) (NN board) )',
#  '        (PP-CLR (IN as) ',
#  '          (NP (DT a) (JJ nonexecutive) (NN director) ))',
#  '        (NP-TMP (NNP Nov.) (CD 29) )))',
#  '    (. .) ))',
#  '( (S ',
#  '    (NP-SBJ (NNP Mr.) (NNP Vinken) )',
#  '    (VP (VBZ is) ',
#  '      (NP-PRD ',
#  '        (NP (NN chairman) )',
#  '        (PP (IN of) ',
#  '          (NP ',
#  '            (NP (NNP Elsevier) (NNP N.V.) )',
#  '            (, ,) ',
#  '            (NP (DT the) (NNP Dutch) (VBG publishing) (NN group) )))))',
#  '    (. .) ))',
#  '',
#  '( (S ',
#  '    (NP-SBJ-1 ',
#  '      (NP (NNP Rudolph) (NNP Agnew) )',
#  '      (, ,) ',
#  '      (UCP ',
#  '        (ADJP ',
#  '          (NP (CD 55) (NNS years) )',
# ...

# %%
# read file to stream
treebank.open
data = treebank.open("wsj_0011.mrg")
print(data)

# %%
# prop:此語料庫的位置
treebank.root
# Out:
# FileSystemPathPointer('C:\\Users\\s1900\\AppData\\Roaming\\nltk_data\\corpora\\treebank\\combined')

# %%
# 印出該語料庫所有的 fileid
treebank.fileids()
# Out:
# ['wsj_0001.mrg',
#  'wsj_0002.mrg',
#  'wsj_0003.mrg',
#  'wsj_0004.mrg',
#  'wsj_0005.mrg',
#  'wsj_0006.mrg',
#  'wsj_0007.mrg',
#  'wsj_0008.mrg',
#  'wsj_0009.mrg',
#  'wsj_0010.mrg',
#  'wsj_0011.mrg',
#  'wsj_0012.mrg',
#  'wsj_0013.mrg',
#  'wsj_0014.mrg',
#  'wsj_0015.mrg',
#  'wsj_0016.mrg',
#  'wsj_0017.mrg',
#  'wsj_0018.mrg',
#  'wsj_0019.mrg',
#  'wsj_0020.mrg',
#  'wsj_0021.mrg',
#  'wsj_0022.mrg',
#  'wsj_0023.mrg',
#  'wsj_0024.mrg',
#  'wsj_0025.mrg',
#  'wsj_0026.mrg',
#  'wsj_0027.mrg',
#  'wsj_0028.mrg',
#  'wsj_0029.mrg',
#  'wsj_0030.mrg',
#  'wsj_0031.mrg',
#  'wsj_0032.mrg',
#  'wsj_0033.mrg',
#  'wsj_0034.mrg',
#  'wsj_0035.mrg',
#  'wsj_0036.mrg',
#  'wsj_0037.mrg',
#  'wsj_0038.mrg',
#  'wsj_0039.mrg',
#  'wsj_0040.mrg',
#  'wsj_0041.mrg',
#  'wsj_0042.mrg',
#  'wsj_0043.mrg',
#  'wsj_0044.mrg',
#  'wsj_0045.mrg',
#  'wsj_0046.mrg',
#  'wsj_0047.mrg',
#  'wsj_0048.mrg',
#  'wsj_0049.mrg',
#  'wsj_0050.mrg',
#  'wsj_0051.mrg',
#  'wsj_0052.mrg',
# ...

# %%
# 印出 abs path, 參數一為 fileid
treebank.abspath("wsj_0011.mrg")
# Out:
# FileSystemPathPointer('C:\\Users\\s1900\\AppData\\Roaming\\nltk_data\\corpora\\treebank\\combined\\wsj_0011.mrg')

# %%
# 語料庫某個 file 的 encoding
treebank.encoding("wsj_0011.mrg")
# Out:
# 'ascii'

# %%
# 印出 license, 若有才會印出, 必須搭配 try, except 接住 exception
try:
    treebank.license()
except Exception as e:
    print(e)
# Out:
# No such file or directory: 'C:\\Users\\s1900\\AppData\\Roaming\\nltk_data\\corpora\\treebank\\combined\\LICENSE'

# %%
# readme about this corpus
treebank.readme().split("\n")
# Out:
# ['[ PENN TREEBANK SAMPLE ]\r',
#  'http://www.cis.upenn.edu/~treebank/home.html\r',
#  '\r',
#  'This is a ~5% fragment of Penn Treebank, (C) LDC 1995.  It is made\r',
#  'available under fair use for the purposes of illustrating NLTK tools\r',
#  'for tokenizing, tagging, chunking and parsing.  This data is for\r',
#  'non-commercial use only.\r',
#  '\r',
#  'Contents: raw, tagged, parsed and combined data from Wall Street\r',
#  'Journal for 1650 sentences (99 treebank files wsj_0001 .. wsj_0099).\r',
#  'For details about each of the four types, please see the other README\r',
#  'files included in the treebank sample directory.  Examples of the four\r',
#  'types are shown below:\r',
#  '\r',
#  '----raw----\r',
#  'Pierre Vinken, 61 years old, will join the board as a nonexecutive\r',
#  'director Nov. 29.\r',
#  '----tagged----\r',
#  '[ Pierre/NNP Vinken/NNP ]\r',
#  ',/, \r',
#  '[ 61/CD years/NNS ]\r',
#  'old/JJ ,/, will/MD join/VB \r',
#  '[ the/DT board/NN ]\r',
# ...

# %% [markdown]
# ---

# %%
tagged_sentence = nltk.corpus.treebank.tagged_sents(tagset='universal')
print("Number of Tagged Sentences ",len(tagged_sentence))
# for sent in tagged_sentence[:2]:
#     print(type(sent))
#     print(sent)
#     for tup in sent:
#         print("tup:", tup)
# print(test)

# 說明: for sent in tagged_sentence => 取出所有的 sentence
# 說明: for tup in sent  => 取出 sentence (list) 的 tuple , tuple like ('Pierre', 'NOUN')
tagged_words=[tup for sent in tagged_sentence for tup in sent]
print("Total Number of Tagged words", len(tagged_words))

# 使用 set: 去除重複的 word
# set 使用方法： set(list)  => return {"", "", "", "",}
vocab=set([word for word,tag in tagged_words])
# print(vocab)
print("Vocabulary of the Corpus", len(vocab))

# 使用 set: 去除重複的 詞性
tags=set([tag for word,tag in tagged_words])
print("Number of Tags in the Corpus ", len(tags))
print(tags)
# Out:
# Number of Tagged Sentences  3914
# Total Number of Tagged words 100676
# Vocabulary of the Corpus 12408
# Number of Tags in the Corpus  12
# {'PRT', '.', 'VERB', 'DET', 'ADP', 'NOUN', 'X', 'NUM', 'CONJ', 'PRON', 'ADJ', 'ADV'}

# %% [markdown]
# ## Training/Testing set split

# %% [markdown]
# 使用 tagged_sentence(含有 pos tagging), 取出 train_set(訓練資料集), test_set(測試資料集)

# %%
# 利用 train_test_split 來萃取出 train_set, test_set

# test_size=0.5 => 代表 train_set: test_set = 0.5:0.5
# test_size=0.2 => 代表 train_set: test_set = 0.8:0.2
train_set, test_set = train_test_split(tagged_sentence,test_size=0.2, random_state=1234)
print("Number of Sentences in Training Data ",len(train_set))  # 3131 筆資料
print("Number of Sentences in Testing Data ",len(test_set))  # 783 筆資料 (1/4)
print(len(test_set)/len(train_set))
print(test_set)
# Out:
# Number of Sentences in Training Data  3131
# Number of Sentences in Testing Data  783
# 0.25007984669434685
# ...

# %% [markdown]
# ## 準備 training data

# %% [markdown]
# ### 從 train_set, test_set 準備 training data

# %%
import re

# 
def features(sentence,index):
    ### sentence is of the form [w1,w2,w3,..], index is the position of the word in the sentence
    return {
        'is_first_capital':int(sentence[index][0].isupper()),
        'is_first_word': int(index==0),
        'is_last_word':int(index==len(sentence)-1),
        'is_complete_capital': int(sentence[index].upper()==sentence[index]),
        'prev_word':'' if index==0 else sentence[index-1],
        'next_word':'' if index==len(sentence)-1 else sentence[index+1],
        'is_numeric':int(sentence[index].isdigit()),
        'is_alphanumeric': int(bool((re.match('^(?=.*[0-9]$)(?=.*[a-zA-Z])',sentence[index])))),
        'prefix_1':sentence[index][0],
        'prefix_2': sentence[index][:2],
        'prefix_3':sentence[index][:3],
        'prefix_4':sentence[index][:4],
        'suffix_1':sentence[index][-1],
        'suffix_2':sentence[index][-2:],
        'suffix_3':sentence[index][-3:],
        'suffix_4':sentence[index][-4:],
        'word_has_hyphen': 1 if '-' in sentence[index] else 0  
         }
def untag(sentence):
    return [word for word,tag in sentence]


def prepareData(tagged_sentences):
    X,y=[],[]
    for sentences in tagged_sentences:
        X.append([features(untag(sentences), index) for index in range(len(sentences))])
        y.append([tag for word,tag in sentences])
    return X,y

# %%
X_train,y_train=prepareData(train_set)
X_test,y_test=prepareData(test_set)


# X_train like below:
# [[{'is_first_capital': 1,
#    'is_first_word': 1,
#    'is_last_word': 0,
#    'is_complete_capital': 0,
#    'prev_word': '',
#    'next_word': 'Wall',
#    'is_numeric': 0,
#    'is_alphanumeric': 0,
#    'prefix_1': 'O',
#    'prefix_2': 'On',
#    'prefix_3': 'On',
#    'prefix_4': 'On',
#    'suffix_1': 'n',
#    'suffix_2': 'On',
#    'suffix_3': 'On',
#    'suffix_4': 'On',
#    'word_has_hyphen': 0},

# y_train like below:
# [['ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CONJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   '.',
#   'X',
#   'VERB',
#   'NUM',
#   'DET',
#   'ADV',

# %% [markdown]
# ## Train
# - 建立 CRF instance 後
# - 將準備好的 x_train, y_train 帶入 instance 中
# - 開始訓練

# %%
# 參考資源：https://sklearn-crfsuite.readthedocs.io/en/latest/tutorial.html#training

crf = CRF(
    algorithm='lbfgs',
    c1=0.01,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)

crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.01, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %% [markdown]
# ## Evaluation

# %%
y_pred=crf.predict(X_test)
print("y_pred \n", y_pred[0], "\n")
print("F1 score on Test Data ")
print(metrics.flat_f1_score(y_test, y_pred,average='weighted',labels=crf.classes_))
print("F score on Training Data ")
y_pred_train=crf.predict(X_train)
metrics.flat_f1_score(y_train, y_pred_train,average='weighted',labels=crf.classes_)

### Look at class wise score
print(metrics.flat_classification_report(
    y_test, y_pred, labels=crf.classes_, digits=3
))
# Out:
# y_pred
#  ['NOUN', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', '.']
#
# F1 score on Test Data
# 0.9738471726864286
# F score on Training Data
#               precision    recall  f1-score   support
#
#          ADP      0.979     0.985     0.982      1869
#         NOUN      0.966     0.977     0.972      5606
#         CONJ      0.994     0.994     0.994       480
#         VERB      0.964     0.960     0.962      2722
#          ADJ      0.911     0.874     0.892      1274
#            .      1.000     1.000     1.000      2354
#            X      1.000     0.997     0.998      1278
#          NUM      0.991     0.993     0.992       671
#          DET      0.994     0.995     0.994      1695
#          ADV      0.927     0.909     0.918       585
#         PRON      0.998     0.998     0.998       562
#          PRT      0.979     0.982     0.980       614
#
#     accuracy                          0.974     19710
#    macro avg      0.975     0.972     0.974     19710
# ...
